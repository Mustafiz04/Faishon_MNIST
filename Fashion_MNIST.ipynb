# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data  = keras.datasets.fashion_mnist

# %%
(train_image, train_label),(test_image, test_label) = data.load_data()

# %%
train_image = train_image/255.0
test_image = test_image/255.0

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# plt.imshow(train_image[7],cmap=plt.cm.binary)
train_image[7].shape
# Out:
# (28, 28)

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128,activation='relu'),
    keras.layers.Dense(10,activation='softmax')
])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(train_image,train_label,epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 30s 501us/sample - loss: 0.5006 - accuracy: 0.8246
# Epoch 2/5
# 60000/60000 [==============================] - 5s 84us/sample - loss: 0.3787 - accuracy: 0.8624
# Epoch 3/5
# 60000/60000 [==============================] - 5s 84us/sample - loss: 0.3398 - accuracy: 0.8745
# Epoch 4/5
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.3156 - accuracy: 0.8833
# Epoch 5/5
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.2940 - accuracy: 0.8921

# %%
test_loss, test_acc = model.evaluate(test_image,test_label)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print(test_acc)
# Out:
# 0.867

# %%
prediction = model.predict(test_image)
for i in range(5):
    plt.grid(False)
    plt.imshow(test_image[i],cmap=plt.cm.binary)
    plt.xlabel("Actual: " + class_names[test_label[i]])
    plt.title("Prediction "+ class_names[np.argmax(prediction[i])] )
    plt.show()
